#  176.22213836 174.02598587 159.58779248 173.78915203 198.67699003
#  172.29458385 170.2685815  165.69665784 179.45269574 185.15937043
#  165.52815301 169.13216525 172.56992071 154.91100349 168.61982488
#  181.47541025 165.14041766 164.52987061 175.41883425 156.80929053
#  182.30642458 160.41313171 181.30496764 181.56655143 179.00043187
#  155.24672459 170.37111331 171.53806349 172.95998404 177.56892301
#  184.16132545 157.65899604 160.29979471 165.21110883 178.151433
#  158.76811909 171.20882512 176.28049212 173.57593016 152.80869185
#  180.17582964 170.07212734 172.88801145 172.94074891 182.03825669
#  188.16253604 188.11206181 162.15180958 174.8964613  172.74782011
#  181.07304022 176.40844165 167.97919341 170.08028038 187.87769129]
# (array([ 8., 24., 29., 39., 44., 46., 29., 22.,  5.,  4.]),
#  array([145.21970968, 150.56543772, 155.91116575, 161.25689379,
#         166.60262182, 171.94834986, 177.29407789, 182.63980593,
#         187.98553396, 193.331262  , 198.67699003]),
#  <BarContainer object of 10 artists>)

# %%
# Y-axis values
y = [10, 5, 8, 4, 2]
# Function to plot histogram
plt.hist(y)
# Function to show the plot
plt.show()

# %%
# x-axis values
x = [5, 2, 9, 4, 7]
# Y-axis values
y = [10, 5, 8, 4, 2]
# Function to plot scatter
plt.scatter(x, y)
# function to show the plot
plt.show()

# %%
from scipy import constants
print(constants.peta)     #1000000000000000.0
print(constants.tera)     #1000000000000.0
print(constants.giga)     #1000000000.0
print(constants.mega)     #1000000.0
print(constants.kilo)     #1000.0
print(constants.hecto)    #100.0
print(constants.deka)     #10.0
print(constants.deci)     #0.1
print(constants.centi)    #0.01
print(constants.milli)    #0.001
print(constants.micro)    #1e-06
print(constants.nano)     #1e-09
print(constants.pico)     #1e-12
# Out:
# 1000000000000000.0
# 1000000000000.0
# 1000000000.0
# 1000000.0
# 1000.0
# 100.0
# 10.0
# 0.1
# 0.01
# 0.001
# 1e-06
# 1e-09
# 1e-12

# %%
from scipy.sparse import csr_matrix
arr = np.array([0, 0, 0, 0, 0, 1, 1, 0, 2])
print(csr_matrix(arr))
# Out:
#   (0, 5)	1
#   (0, 6)	1
#   (0, 8)	2

# %%
arr = np.array([[0, 0, 0], [0, 0, 1], [1, 0, 2]])
print(csr_matrix(arr).data)
# Out:
# [1 1 2]

# %%
arr = np.array([[0, 0, 0], [0, 0, 1], [1, 0, 2]])
newarr = csr_matrix(arr).tocsc()
print(newarr)
# Out:
#   (2, 0)	1
#   (1, 2)	1
#   (2, 2)	2

# %%
mydataset = {   'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2] }
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
new_series= pd.Series([5,6,7,8,9,10])
print(new_series)
# Out:
# 0     5
# 1     6
# 2     7
# 3     8
# 4     9
# 5    10
# dtype: int64

# %%
new_series= pd.Series([5,6,7,8,9,10])
print(new_series.values)
print('_____________')
print(new_series[4])
# Out:
# [ 5  6  7  8  9 10]
# _____________
# 9

# %%
new_series= pd.Series([5,6,7,8,9,10], index=['a','b','c','d','e','f'])
print(new_series)
print('_____________')
print(new_series.values)
print('_____________')
print(new_series['f'])
# Out:
# a     5
# b     6
# c     7
# d     8
# e     9
# f    10
# dtype: int64
# _____________
# [ 5  6  7  8  9 10]
# _____________
# 10

# %%
new_series= pd.Series([5,6,7,8,9,10], index=['a','b','c','d','e','f'])
print(new_series)
print('_____________')
print(new_series[['b', 'c', 'f']])
# Out:
# a     5
# b     6
# c     7
# d     8
# e     9
# f    10
# dtype: int64
# _____________
# b     6
# c     7
# f    10
# dtype: int64

# %%
new_series= pd.Series([5,6,7,8,9,10], index=['a','b','c','d','e','f'])
new_series2= new_series[new_series>0]  # check with 7 instead of 0
print(new_series2)
print('_____________')
new_series2= new_series[new_series>0]  * 2
print(new_series2)
# Out:
# a     5
# b     6
# c     7
# d     8
# e     9
# f    10
# dtype: int64
# _____________
# a    10
# b    12
# c    14
# d    16
# e    18
# f    20
# dtype: int64

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
#load data into a DataFrame object:
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
list2=[[0,1,2],[3,4,5],[6,7,8]]
df= pd.DataFrame(list2)
print("DataFrame:")
print(df)

# set the column labels
df.columns = ['C1','C2','C3']
print("Column names are Updated:")
print(df)
# Out:
# DataFrame:
#    0  1  2
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8
# Column names are Updated:
#    C1  C2  C3
# 0   0   1   2
# 1   3   4   5
# 2   6   7   8

# %%
df=pd.DataFrame({
      'Country': ['Kazakhstan','Russia','Belarus','Ukraine'],
      'Population': [17.04,143.5,9.5,45.5],
      'Square':[2724902, 17125191,207600,603628]
     })
print(df)
# Out:
#       Country  Population    Square
# 0  Kazakhstan       17.04   2724902
# 1      Russia      143.50  17125191
# 2     Belarus        9.50    207600
# 3     Ukraine       45.50    603628

# %%
df=pd.DataFrame({'Country': ['Kazakhstan','Russia','Belarus','Ukraine'],'Population':[17.04,143.5,9.5,45.5],'Square':[2724902, 17125191,207600,603628]})
print(df.columns)
print('_____________________')
print(df.index)
# Out:
# Index(['Country', 'Population', 'Square'], dtype='object')
# _____________________
# RangeIndex(start=0, stop=4, step=1)

# %%
print(df)
print('_____________________')
df.index = ['KZ','RU','BY','UA']
df.index.name = 'Country Code'
print(df)
# Out:
#       Country  Population    Square
# 0  Kazakhstan       17.04   2724902
# 1      Russia      143.50  17125191
# 2     Belarus        9.50    207600
# 3     Ukraine       45.50    603628
# _____________________
#                  Country  Population    Square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600
# UA               Ukraine       45.50    603628

# %%
print(df.loc['KZ'])
print()
print(df.iloc[0])
print()
print(df.loc[['KZ','RU'],'Population'])
print()
print(df.loc['KZ':'BY', :])
# Out:
# Country       Kazakhstan
# Population         17.04
# Square           2724902
# Name: KZ, dtype: object
#
# Country       Kazakhstan
# Population         17.04
# Square           2724902
# Name: KZ, dtype: object
#
# Country Code
# KZ     17.04
# RU    143.50
# Name: Population, dtype: float64
#
#                  Country  Population    Square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600

# %%
print([[df.Population > 10],'Country','Square'])
# Out:
# [[Country Code
# KZ     True
# RU     True
# BY    False
# UA     True
# Name: Population, dtype: bool], 'Country', 'Square']

# %%
print(df)
df = df.drop(['Population'], axis = 'columns')
print(df)
# Out:
#                  Country  Population    Square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600
# UA               Ukraine       45.50    603628
#                  Country    Square
# Country Code
# KZ            Kazakhstan   2724902
# RU                Russia  17125191
# BY               Belarus    207600
# UA               Ukraine    603628

# %%
import pandas as pd
df=pd.DataFrame({
    'Country': ['Kazakhstan','Russia','Belarus','Ukraine'],  
    'Population': [17.04,143.5,9.5,45.5],
     'Square':[2724902,17125191,207600,603628],
     })
print(df)
print('1_____________________')
df.index = ['KZ','RU','BY','UA']
df.index.name = 'Country Code'
print(df)
print('_2____________________')
print(df.loc['KZ'])
print('3_____________________')
print(df.iloc[0])
print('4_____________________')
print(df.loc[['KZ','RU'],'Population'])
print('5_____________________')
print(df.loc['KZ':'UA', :])
print('6_____________________')
print([[df.Population > 10],'Country','Square'])
print('7____________________')
print(df)
print('8_____________________')
df = df.drop(['Population'], axis = 'columns')
print(df)
print('9_____________________')
# Out:
#       Country  Population    Square
# 0  Kazakhstan       17.04   2724902
# 1      Russia      143.50  17125191
# 2     Belarus        9.50    207600
# 3     Ukraine       45.50    603628
# 1_____________________
#                  Country  Population    Square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600
# UA               Ukraine       45.50    603628
# _2____________________
# Country       Kazakhstan
# Population         17.04
# Square           2724902
# Name: KZ, dtype: object
# 3_____________________
# Country       Kazakhstan
# Population         17.04
# Square           2724902
# Name: KZ, dtype: object
# 4_____________________
# Country Code
# KZ     17.04
# RU    143.50
# Name: Population, dtype: float64
# 5_____________________
#                  Country  Population    Square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600
# UA               Ukraine       45.50    603628
# 6_____________________
# [[Country Code
# KZ     True
# RU     True
# BY    False
# UA     True
# Name: Population, dtype: bool], 'Country', 'Square']
# 7____________________
#                  Country  Population    Square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600
# UA               Ukraine       45.50    603628
# 8_____________________
#                  Country    Square
# Country Code
# KZ            Kazakhstan   2724902
# RU                Russia  17125191
# BY               Belarus    207600
# UA               Ukraine    603628
# 9_____________________
